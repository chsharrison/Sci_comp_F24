# %% [markdown]
# Name Zhenwei Wu

# %% [markdown]
# Lab Partner

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

import numpy as np
import matplotlib.pyplot as plt

# %%
whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>

# %%
who
# Out:
# np	 plt

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# Today we are going to continue working on what we started last time, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Moodle.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
# variables about my name
var1 = "Zhenwei Wu"

# variables about my age5
var2 = "26"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
#print ou type of var1
print(type(var1))
# Out:
# <class 'str'>

# %%
#convert var2 to int
var2 = int(var2)

#verify
print(var2)
print(type(var2))
# Out:
# 26
# <class 'int'>

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
#using len() to show the number of characters
print(len(var1))
# Out:
# 10

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
#using .upper() to do this
upper_var1 = var1.upper()
print(upper_var1)
# Out:
# ZHENWEI WU

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
list1 = [var1, var2]
print(list1)
# Out:
# ['Zhenwei Wu', 26]

# %%
#using np.array() to convert a list into a numpy array
array1 = np.array(list1)
print(array1)

#tips: array can only contain one kind of variable. for example: str or int or float
# Out:
# ['Zhenwei Wu' '26']

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
#using np.append() to append something in a array
array2 = np.append( array1, "orange")
print(array2)
# Out:
# ['Zhenwei Wu' '26' 'orange']

# %% [markdown]
# **W7** Print the reverse of the array

# %%
#using np.flip() function to reverse a array
array3 = np.flip(array2)
print(array3)
# Out:
# ['orange' '26' 'Zhenwei Wu']

# %% [markdown]
# **W8** Make a new variable, var3 that is equal to var2 * pi. (Hint: You will need to do a type conversion)

# %%
#define pi using np.pi
np.pi
# Out:
# 3.141592653589793

# %%
var3 = var2 *np.pi
print(var3)
print(type(var3))
# Out:
# 81.68140899333463
# <class 'float'>

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
#using np.append() to append var3 to array
array4 = np.append(array2, var3)
print(array4)
# Out:
# ['Zhenwei Wu' '26' 'orange' '81.68140899333463']

# %% [markdown]
# # Lecture 3.1

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %% [markdown]
# Questions

# %% [markdown]
# **Postponed until next week! Get your questions ready for next Tuesday**

# %%
#first thing is to put some data
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

# %%
#then we need to define a plot
fig,ax = plt.subplots()

# %%
plt.bar?
# Out:
# Signature:
# plt.bar(
#     x,
#     height,
#     width=0.8,
#     bottom=None,
#     *,
#     align='center',
#     data=None,
#     **kwargs,
# )
# Docstring:
# Make a bar plot.
#
# The bars are positioned at *x* with the given *align*\ment. Their
# dimensions are given by *height* and *width*. The vertical baseline
# is *bottom* (default 0).
#
# Many parameters can take either a single value applying to all bars
# or a sequence of values, one for each bar.
#
# Parameters
# ----------
# x : float or array-like
#     The x coordinates of the bars. See also *align* for the
#     alignment of the bars to the coordinates.
#
# height : float or array-like
#     The height(s) of the bars.
#
# width : float or array-like, default: 0.8
#     The width(s) of the bars.
#
# bottom : float or array-like, default: 0
#     The y coordinate(s) of the bottom side(s) of the bars.
#
# align : {'center', 'edge'}, default: 'center'
#     Alignment of the bars to the *x* coordinates:
#
# ...

# %%
# we can first try to show labels and men_means data on the plot without width limit
fig,ax = plt.subplots()
ax.bar(labels, men_means)

# it's maybe too fat, bc the default is 0.8
# Out:
# <BarContainer object of 5 artists>

# %%
# now let us try to limit width for tis plot
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width)
# Out:
# <BarContainer object of 5 artists>

# %%
# now let's add std
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std)
# Out:
# <BarContainer object of 5 artists>

# %%
# now let's add label using .legend()
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std, label = "Men")
ax.legend()

# %%
# now we add women data
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std, label = "Men")
ax.bar(labels, women_means, width = bar_width, yerr = women_std, label = "Women")
ax.legend()
# now we can see women data cover part of men data, so we need "bottom" to show whcih data should in the bottom of another

# %%
# using "bottom"
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std, label = "Men")
ax.bar(labels, women_means, width = bar_width, yerr = women_std, bottom = men_means, label = "Women")
ax.legend()

# %%
# add y-label and title. We have two ways. Here is the first using ax.set_ylabel() and ax.set_title()
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std, label = "Men")
ax.bar(labels, women_means, width = bar_width, yerr = women_std, bottom = men_means, label = "Women")
ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.legend()

# %%
# now let's try th eother way, using plt.ylabel() and plt.title() function
bar_width = 0.55
fig,ax = plt.subplots()
ax.bar(labels, men_means, width = bar_width, yerr = men_std, label = "Men")
ax.bar(labels, women_means, width = bar_width, yerr = women_std, bottom = men_means, label = "Women")
plt.ylabel("Scores")
plt.title("Scores by group and gender")
ax.legend()

# %%
# let's go over an example plot in the old matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.55       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots() # defining a figure

ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

plt.ylabel('Scores')
#ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# **E.1** Finish Lab 2.2 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the examples gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). For each exercise pick a different type of plot (line, scatter, bar, etc.). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain in words what type of data each kind plot would be useful for showing.

# %%
#First of all, import package. Basically these can be used for every diagram. 
import numpy as np
import matplotlib.pyplot as plt

# %%
#E.3 Let's try bar chart first. A bar chart is used to compare the values of different categories or groups.

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

#  i can change y-label and title by changing here. 
ax.set_ylabel('goods supply')
ax.set_title('Goods supply by kind and color')
ax.legend(title='Goods color')

plt.show()

# %%
# E.4 Then we can try Grouped bar chart with labels. 
# A grouped bar chart can be used to compare multiple sets of data across different categories by grouping bars 
# side by side for each category, allowing for more detailed comparisons.

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

#You can change bar color by adding a line of code to determine color of bars. 
colors = ['red', 'purple', 'cyan']  # Example: blue, orange, green

#Then you need to add i in this for loop.
for i, (attribute, measurement) in enumerate(penguin_means.items()):
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[i])
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

#You can change bar color by adding a line of code to determine color of bars. 
colors = ['red', 'purple', 'cyan']  # Example: blue, orange, green

#Then you need to add i in this for loop.
for i, (attribute, measurement) in enumerate(penguin_means.items()):
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[i])
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)

#You can change position of legend by changing this.
ax.legend(loc='upper right', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
# E.5 We try plotting the coherence of two signals. 
# Coherence plotting shows signal correlation across different frequency ranges.

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, s1, t, s2)   # s1 with blue color
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

# you can change color of s1 and s2 by defining them here
fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, s1, color='black', label='s1')   # s1 with blue color
axs[0].plot(t, s2, color='red', label='s2') # s2 with orange color
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# You can change time step here simply. 
dt = 0.001
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

# you can change color of s1 and s2 by defining them here
fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, s1, color='black', label='s1')   # s1 with blue color
axs[0].plot(t, s2, color='red', label='s2') # s2 with orange color
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

plt.show()

# %%
# E.6 Then we gonna try Confidence bands.

# %% [markdown]
# A confidence band in statistics represents the uncertainty around a regression line, showing the range within which the true regression line is expected to fall with a certain confidence level.

# %%
N = 21
x = np.linspace(0, 10, 11)
y = [3.9, 4.4, 10.8, 10.3, 11.2, 13.1, 14.1,  9.9, 13.9, 15.1, 12.5]

# fit a linear curve and estimate its y-values and their error.
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1/len(x) +
                          (x - x.mean())**2 / np.sum((x - x.mean())**2))

fig, ax = plt.subplots()
ax.plot(x, y_est, '-')

# We can use fill_between function to do the indication of confidence bands.
ax.fill_between(x, y_est - y_err, y_est + y_err, alpha=0.2)
ax.plot(x, y, 'o', color='tab:brown')

# %%
N = 21
x = np.linspace(0, 10, 11)
y = [3.9, 4.4, 10.8, 10.3, 11.2, 13.1, 14.1,  9.9, 13.9, 15.1, 12.5]

# fit a linear curve and estimate its y-values and their error.
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1/len(x) +
                          (x - x.mean())**2 / np.sum((x - x.mean())**2))

fig, ax = plt.subplots()
ax.plot(x, y_est, '-')

# We can use fill_between function to do the indication of confidence bands.
ax.fill_between(x, y_est - y_err, y_est + y_err, alpha=0.2)

# You can change color of dots by changing this.
ax.plot(x, y, 'o', color='tab:red')

# %%
N = 21
x = np.linspace(0, 10, 11)
y = [3.9, 4.4, 10.8, 10.3, 11.2, 13.1, 14.1,  9.9, 13.9, 15.1, 12.5]

# fit a linear curve and estimate its y-values and their error.
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1/len(x) +
                          (x - x.mean())**2 / np.sum((x - x.mean())**2))

fig, ax = plt.subplots()
ax.plot(x, y_est, '-')

# You can change the color of the confidence area in your plot by adding argument here.
ax.fill_between(x, y_est - y_err, y_est + y_err, color='grey', alpha=0.2)
ax.plot(x, y, 'o', color='tab:brown')

# %%
# E.7 Then we try violoin plot.

# %%
# A violin plot is used to visualize the distribution, density, and probability of data across different categories

# %%
np.random.seed(19680801)

# Generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# Create a single figure and axis
fig, ax = plt.subplots( figsize=(6, 4))

# Plot violin plot
ax.violinplot(all_data,
              showmeans=False,
              showmedians=True)
ax.set_title('Violin plot')

# Add horizontal grid lines
ax.yaxis.grid(True)
ax.set_xticks([y + 1 for y in range(len(all_data))],
              labels=['x1', 'x2', 'x3', 'x4'])
ax.set_xlabel('Four separate samples')
ax.set_ylabel('Observed values')

plt.show()

# %%
np.random.seed(19680801)

# Generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# Create a single figure and axis (only one plot)
fig, ax = plt.subplots( figsize=(6, 4))

# Plot violin plot
ax.violinplot(all_data,
              showmeans=False,
              showmedians=True)
ax.set_title('Violin plot')

# Add horizontal grid lines
ax.yaxis.grid(True)
ax.set_xticks([y + 1 for y in range(len(all_data))],
              labels=['x1', 'x2', 'x3', 'x4'])
ax.set_xlabel('Four separate samples')
ax.set_ylabel('Observed values')

plt.show()

# %%
np.random.seed(19680801)

# Generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# Create a single figure and axis
fig, ax = plt.subplots(figsize=(6, 4))

# Plot violin plot
violins = ax.violinplot(all_data, showmeans=False, showmedians=True)

# Change the color of each violin area
colors = ['lightblue', 'lightgreen', 'lightpink', 'lightyellow']
for i, body in enumerate(violins['bodies']):
    body.set_facecolor(colors[i])  # Set custom color for each violin
    body.set_edgecolor('black')    # Optionally set edge color
    body.set_alpha(0.7)            # Adjust transparency (alpha value)

ax.set_title('Violin plot')

# Add horizontal grid lines
ax.yaxis.grid(True)
ax.set_xticks([y + 1 for y in range(len(all_data))], labels=['x1', 'x2', 'x3', 'x4'])
ax.set_xlabel('Four separate samples')
ax.set_ylabel('Observed values')

plt.show()

# %%
np.random.seed(19680801)

# Generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# Create a single figure and axis
fig, ax = plt.subplots(figsize=(6, 4))

# Plot violin plot
violins = ax.violinplot(all_data, showmeans=False, showmedians=True)

# Change the color of each violin area
colors = ['lightblue', 'lightgreen', 'lightpink', 'lightyellow']
for i, body in enumerate(violins['bodies']):
    body.set_facecolor(colors[i])  # Set custom color for each violin
    body.set_edgecolor('black')    # Optionally set edge color
    body.set_alpha(0.7)            # Adjust transparency (alpha value)

# Add vertical lines (along the y-axis) for each violin plot
for i in range(1, len(all_data) + 1):
    ax.axvline(x=i, color='gray', linestyle='--', alpha=0.5)  # Vertical lines at each violin position

ax.set_title('Violin plot')

# Add horizontal grid lines
ax.yaxis.grid(True)
ax.set_xticks([y + 1 for y in range(len(all_data))], labels=['x1', 'x2', 'x3', 'x4'])
ax.set_xlabel('Four separate samples')
ax.set_ylabel('Observed values')

plt.show()

# %%
# E.8 Time Series Histogram

# %%
# I dont know what is this, but it is beautiful.

# %% [markdown]
# It seems like A time series histogram is used to display the frequency distribution of values within a time series, helping to identify patterns, trends, or anomalies over time.

# %%
import time

fig, axes = plt.subplots(nrows=3, figsize=(6, 8), layout='constrained')

# Fix random state for reproducibility
np.random.seed(19680801)
# Make some data; a 1D random walk + small fraction of sine waves
num_series = 1000
num_points = 100
SNR = 0.10  # Signal to Noise Ratio
x = np.linspace(0, 4 * np.pi, num_points)
# Generate unbiased Gaussian random walks
Y = np.cumsum(np.random.randn(num_series, num_points), axis=-1)
# Generate sinusoidal signals
num_signal = round(SNR * num_series)
phi = (np.pi / 8) * np.random.randn(num_signal, 1)  # small random offset
Y[-num_signal:] = (
    np.sqrt(np.arange(num_points))  # random walk RMS scaling factor
    * (np.sin(x - phi)
       + 0.05 * np.random.randn(num_signal, num_points))  # small random noise
)


# Plot series using `plot` and a small value of `alpha`. With this view it is
# very difficult to observe the sinusoidal behavior because of how many
# overlapping series there are. It also takes a bit of time to run because so
# many individual artists need to be generated.
tic = time.time()
axes[0].plot(x, Y.T, color="C0", alpha=0.1)
toc = time.time()
axes[0].set_title("Line plot with alpha")
print(f"{toc-tic:.3f} sec. elapsed")


# Now we will convert the multiple time series into a histogram. Not only will
# the hidden signal be more visible, but it is also a much quicker procedure.
tic = time.time()
# Linearly interpolate between the points in each time series
num_fine = 800
x_fine = np.linspace(x.min(), x.max(), num_fine)
y_fine = np.concatenate([np.interp(x_fine, x, y_row) for y_row in Y])
x_fine = np.broadcast_to(x_fine, (num_series, num_fine)).ravel()


# Plot (x, y) points in 2d histogram with log colorscale
# It is pretty evident that there is some kind of structure under the noise
# You can tune vmax to make signal more visible
cmap = plt.colormaps["plasma"]
cmap = cmap.with_extremes(bad=cmap(0))
h, xedges, yedges = np.histogram2d(x_fine, y_fine, bins=[400, 100])
pcm = axes[1].pcolormesh(xedges, yedges, h.T, cmap=cmap,
                         norm="log", vmax=1.5e2, rasterized=True)
fig.colorbar(pcm, ax=axes[1], label="# points", pad=0)
axes[1].set_title("2d histogram and log color scale")

# Same data but on linear color scale
pcm = axes[2].pcolormesh(xedges, yedges, h.T, cmap=cmap,
                         vmax=1.5e2, rasterized=True)
fig.colorbar(pcm, ax=axes[2], label="# points", pad=0)
axes[2].set_title("2d histogram and linear color scale")

toc = time.time()
print(f"{toc-tic:.3f} sec. elapsed")
plt.show()
# Out:
# 0.201 sec. elapsed
# 0.097 sec. elapsed

# %%
fig, axes = plt.subplots(nrows=3, figsize=(6, 8), layout='constrained')

# Fix random state for reproducibility
np.random.seed(19680801)
# Make some data; a 1D random walk + small fraction of sine waves
num_series = 1000
num_points = 100
SNR = 0.10  # Signal to Noise Ratio
x = np.linspace(0, 4 * np.pi, num_points)
# Generate unbiased Gaussian random walks
Y = np.cumsum(np.random.randn(num_series, num_points), axis=-1)
# Generate sinusoidal signals
num_signal = round(SNR * num_series)
phi = (np.pi / 8) * np.random.randn(num_signal, 1)  # small random offset
Y[-num_signal:] = (
    np.sqrt(np.arange(num_points))  # random walk RMS scaling factor
    * (np.sin(x - phi)
       + 0.05 * np.random.randn(num_signal, num_points))  # small random noise
)


# Plot series using `plot` and a small value of `alpha`. With this view it is
# very difficult to observe the sinusoidal behavior because of how many
# overlapping series there are. It also takes a bit of time to run because so
# many individual artists need to be generated.
tic = time.time()
axes[0].plot(x, Y.T, color="C0", alpha=0.1)
toc = time.time()
axes[0].set_title("Line plot with alpha")
print(f"{toc-tic:.3f} sec. elapsed")


# Now we will convert the multiple time series into a histogram. Not only will
# the hidden signal be more visible, but it is also a much quicker procedure.
tic = time.time()

# Custom color for line plot
axes[0].plot(x, Y.T, color="green", alpha=0.1)  # Changed to red
axes[0].set_title("Line plot with alpha")
toc = time.time()
print(f"{toc - tic:.3f} sec. elapsed")

# Linearly interpolate between the points in each time series
num_fine = 800
x_fine = np.linspace(x.min(), x.max(), num_fine)
y_fine = np.concatenate([np.interp(x_fine, x, y_row) for y_row in Y])
x_fine = np.broadcast_to(x_fine, (num_series, num_fine)).ravel()


# Plot (x, y) points in 2d histogram with log colorscale
# It is pretty evident that there is some kind of structure under the noise
# You can tune vmax to make signal more visible
cmap = plt.colormaps["plasma"]
cmap = cmap.with_extremes(bad=cmap(0))
h, xedges, yedges = np.histogram2d(x_fine, y_fine, bins=[400, 100])
pcm = axes[1].pcolormesh(xedges, yedges, h.T, cmap=cmap,
                         norm="log", vmax=1.5e2, rasterized=True)
fig.colorbar(pcm, ax=axes[1], label="# points", pad=0)
axes[1].set_title("2d histogram and log color scale")

# Same data but on linear color scale
pcm = axes[2].pcolormesh(xedges, yedges, h.T, cmap=cmap,
                         vmax=1.5e2, rasterized=True)
fig.colorbar(pcm, ax=axes[2], label="# points", pad=0)
axes[2].set_title("2d histogram and linear color scale")

toc = time.time()
print(f"{toc-tic:.3f} sec. elapsed")
plt.show()
# Out:
# 0.221 sec. elapsed
# 0.652 sec. elapsed
# 0.731 sec. elapsed
