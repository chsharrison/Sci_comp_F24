# %% [markdown]
# Name Owhonda Ihunwo

# %% [markdown]
# Lab Partner

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

import numpy as np
import matplotlib.pyplot as plt

# %%
whos
# Out:
# Variable               Type             Data/Info
# -------------------------------------------------
# NamespaceMagics        MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# dataframe_columns      function         <function dataframe_colum<...>ns at 0x000002C23C603920>
# dataframe_hash         function         <function dataframe_hash at 0x000002C23C603D80>
# dtypes_str             function         <function dtypes_str at 0x000002C23C603880>
# get_dataframes         function         <function get_dataframes at 0x000002C23DC32DE0>
# get_ipython            function         <function get_ipython at 0x000002C2396F8180>
# getpass                module           <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module           <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function         <function import_pandas_s<...>ly at 0x000002C2402A68E0>
# is_data_frame          function         <function is_data_frame at 0x000002C23C603380>
# json                   module           <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>
# np                     module           <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# plt                    module           <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sys                    module           <module 'sys' (built-in)>

# %%
who
# Out:
# NamespaceMagics	 dataframe_columns	 dataframe_hash	 dtypes_str	 get_dataframes	 get_ipython	 getpass	 hashlib	 import_pandas_safely
# is_data_frame	 json	 np	 plt	 sys

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# Today we are going to continue working on what we started last time, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Moodle.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1 = "Owhonda Ihunwo"
var2 = "38"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
var1 = "Owhonda Ihunwo"
var2 = "38"

print(type(var1))
var2 = int(var2)
print(type(var2))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
var1 = "Owhonda Ihunwo"
print(len(var1))
# Out:
# 14

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
name = "Owhonda Ihunwo"
capitalized_name = name.upper()
print(capitalized_name)
# Out:
# OWHONDA IHUNWO

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
var1 = "Owhonda Ihunwo"
var2 = 38

combined_list = [var1, var2]
combined_array = np.array(combined_list)

print(combined_array)
# Out:
# ['Owhonda Ihunwo' '38']

# %%
#to convert the string to a numerical value (e.g., the length of the string), you can do so before creating the array:
combined_list = [len(var1), var2]
combined_array = np.array(combined_list)

print(combined_array)
# Out:
# [14 38]

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
var1 = "Owhonda Ihunwo"
var2 = 38

combined_list = [len(var1), var2]
combined_array = np.array(combined_list)

# Append the favorite color to the array
combined_array = np.append(combined_array, "Red")

print(combined_array)
# Out:
# ['14' '38' 'Red']

# %% [markdown]
# **W7** Print the reverse of the array

# %%
var1 = "Owhonda Ihunwo"
var2 = 38

combined_list = [len(var1), var2]
combined_array = np.array(combined_list)

# Append the favorite color to the array
combined_array = np.append(combined_array, "Red")

# Print the reverse of the array
print(np.flip(combined_array))
# Out:
# ['Red' '38' '14']

# %% [markdown]
# **W8** Make a new variable, var3 that is equal to var2 * pi. (Hint: You will need to do a type conversion)

# %%
var1 = "Owhonda Ihunwo"
var2 = 38

# Convert var2 to float and multiply by pi
var3 = float(var2) * np.pi

print(var3)
# Out:
# 119.38052083641213

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
var1 = "Owhonda Ihunwo"
var2 = 38

combined_list = [len(var1), var2]
combined_array = np.array(combined_list)

# Append the favorite color to the array
combined_array = np.append(combined_array, "Red")

# Convert var2 to float and multiply by pi
var3 = float(var2) * np.pi

# Append var3 to the array
combined_array = np.append(combined_array, var3)

# Print the array
print(combined_array)
# Out:
# ['14' '38' 'Red' '119.38052083641213']

# %% [markdown]
# # Lecture 3.1

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %% [markdown]
# Questions

# %% [markdown]
# **Postponed until next week! Get your questions ready for next Tuesday**

# %%
# let's go over an example plot in the old matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.55       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots() # defining a figure

ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

plt.ylabel('Scores')
#ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Lab 3.1

# %% [markdown]
# **E.1** Finish Lab 2.2 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the examples gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). For each exercise pick a different type of plot (line, scatter, bar, etc.). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain in words what type of data each kind plot would be useful for showing.

# %%
#Grouped bar chart with labels

import matplotlib.pyplot as plt
import numpy as np

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  
width = 0.25  
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
#Modified plot species name
species = ("Ephemeroptera", "Plecoptera", "Tricoptera")
penguin_means = {
    'No of species': (18.35, 18.43, 14.98),
    'No of taxa': (38.79, 48.83, 47.50),
    'No of individuals': (189.95, 195.82, 217.19),
}

x = np.arange(len(species)) 

#change bar width size
width = 0.1
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
#Scatter plots with a legend
N = 45
x, y = np.random.rand(2, N)
c = np.random.randint(1, 5, size=N)
s = np.random.randint(10, 220, size=N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c, s=s)

r
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)


handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

plt.show()

# %%
#Modified plot
N = 200
x, y = np.random.rand(2, N)
c = np.random.randint(2, 50, size=N)
s = np.random.randint(10, 150, size=N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c, s=s)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper left", title="Species")
ax.add_artist(legend1)

# produce a legend with a cross-section of sizes from the scatter
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.1)
legend2 = ax.legend(handles, labels, loc="lower right", title="sizes")

plt.show()

# %%
import matplotlib.colors as colors

def rbf(x, y):
    return 1.0 / (1 + 5 * ((x ** 2) + (y ** 2)))

N = 1000
gain = 5
X, Y = np.mgrid[-3:3:complex(0, N), -2:2:complex(0, N)]
Z1 = rbf(X + 0.5, Y + 0.5)
Z2 = rbf(X - 0.5, Y - 0.5)
Z = gain * Z1 - Z2

shadeopts = {'cmap': 'PRGn', 'shading': 'gouraud'}
colormap = 'PRGn'
lnrwidth = 0.5

fig, ax = plt.subplots(2, 1, sharex=True, sharey=True)

pcm = ax[0].pcolormesh(X, Y, Z,
                       norm=colors.SymLogNorm(linthresh=lnrwidth, linscale=1,
                                              vmin=-gain, vmax=gain, base=10),
                       **shadeopts)
fig.colorbar(pcm, ax=ax[0], extend='both')
ax[0].text(-2.5, 1.5, 'symlog')

pcm = ax[1].pcolormesh(X, Y, Z, vmin=-gain, vmax=gain,
                       **shadeopts)
fig.colorbar(pcm, ax=ax[1], extend='both')
ax[1].text(-2.5, 1.5, 'linear')
# Out:
# Text(-2.5, 1.5, 'linear')

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.colors as colors


def rbf(x, y):
    return 1.0 / (1 + 5 * ((x ** 2) + (y ** 2)))

N = 1000
gain = 2
X, Y = np.mgrid[-3:3:complex(0, N), -2:2:complex(0, N)]
Z1 = rbf(X + 0.9, Y + 0.9)
Z2 = rbf(X - 0.9, Y - 0.9)
Z = gain * Z1 - Z2

shadeopts = {'cmap': 'PRGn', 'shading': 'gouraud'}
colormap = 'PRGn'
lnrwidth = 0.1

fig, ax = plt.subplots(2, 1, sharex=True, sharey=True)

pcm = ax[0].pcolormesh(X, Y, Z,
                       norm=colors.SymLogNorm(linthresh=lnrwidth, linscale=1,
                                              vmin=-gain, vmax=gain, base=10),
                       **shadeopts)
fig.colorbar(pcm, ax=ax[0], extend='both')
ax[0].text(-2.5, 1.5, 'Species diversity')

pcm = ax[1].pcolormesh(X, Y, Z, vmin=-gain, vmax=gain,
                       **shadeopts)
fig.colorbar(pcm, ax=ax[1], extend='both')
ax[1].text(-2.5, 1.5, 'pH')
# Out:
# Text(-2.5, 1.5, 'pH')

# %%
# %connect_info
# Out:
# {
#   "shell_port": 64784,
#   "iopub_port": 64785,
#   "stdin_port": 64786,
#   "control_port": 64788,
#   "hb_port": 64787,
#   "ip": "127.0.0.1",
#   "key": "5aa1fae6-5019059f9a3586f2bbf0aa64",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": "python3",
#   "jupyter_session": "C:\\Users\\owhon\\Lab3.1_F24.ipynb"
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-fe98fd7d-dfb7-47d5-84bb-cde76ca69c1d.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
