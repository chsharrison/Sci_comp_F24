# %% [markdown]
# Name: Sarah Brannum

# %% [markdown]
# Lab Partner(s): N/A

# %%
# import statements go here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  #new package!!

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today I will show you how to import simple data files. We are using a new package, Pandas, which I will introduce and then you will explore more in datacamp.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W.1.** Make a numpy array that goes from 100 to 1000 (including 1000) stepping by 50

# %%
array1=np.array(range(100,1000,50))
print(array1)
# Out:
# [100 150 200 250 300 350 400 450 500 550 600 650 700 750 800 850 900 950]

# %% [markdown]
# **W.2** What is the shape of this array (this is not about plotting, but the size of the array, how many elements does it have? Find this using python)

# %%
dir(array1)
array1.shape
# the shape is 18x1, and there are 18 total items
# Out:
# (18,)

# %% [markdown]
# **W.3.1** Print out the first 5 elements of the array

# %%
print(array1[0:5])
# Out:
# [100 150 200 250 300]

# %% [markdown]
# **W.3.2** Print out the last 5 elements of the array

# %%
print(array1[-5:])
# Out:
# [750 800 850 900 950]

# %% [markdown]
# **W.3.3** Print out the sith through tenth elements of the array. There should be five elements printed

# %%
print(array1[5:10])
# Out:
# [350 400 450 500 550]

# %% [markdown]
# **W.4.1** Plot the array (i.e. plt.plot(x) if x is your array) and make your line red

# %%
plt.plot(array1,color='red')

# %% [markdown]
# **W.4.2** What is being plotted on the x-axis?

# %%
#the position in the array

# %% [markdown]
# **W.4.3** Label your axes reflecting your answer above and add a title

# %%
plt.xlabel('position in array')
plt.ylabel('value')
plt.plot(array1,color='red')

# %% [markdown]
# **W.5** Now calculate the square of your array, i.e. $x^2$ and plot this vs the first array, i.e. plt.plot(x,$x^2$). What is being plotted on the x-axis now? Label your axes and add a legend.

# %%
array2=array1**2
plt.xlabel('x')
plt.ylabel('x squared')
plt.plot(array1,array2,color='magenta',label='line')
plt.legend()


#The x axis is plotting the x number, while the y axis is plotting x^2

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# ### 3.2.1 What are all the questions from the previous labs and material?
# The more basic the better. Let's do some review and make sure we don't leave anyone behind.

# %% [markdown]
# **We will do this on Tuesday, bring your questions**
#
# You might note them here for reference

# %% [markdown]
# ### 3.2.2 How to import a text file (the old ways of python)

# %% [markdown]
# We are going to use some data in the scipy lecture notes, which is a great reference:
#
# http://scipy-lectures.org/intro/numpy/exercises.html#data-statistics
#
# Note that I have downloaded the populations.txt file and put it in the same foler as this notebook, so I can load it without the path in front

# %%
#Note that I have downloaded the populations.txt file and put it in the same foler as this notebook, so I can load it without the path in front

data = np.loadtxt('populations.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 #Note that I have downloaded the populations.txt file and put it in the same foler as this notebook, so I can load it without the path in front
# ----> 3 data = np.loadtxt('populations.txt')
#
# File ~\AppData\Local\anaconda3again\envs\OCS4001_2\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
# ...

# %%
data

# %%
# note if the data file is in another folder, I have to add some path information to the file string

data2 = np.loadtxt('/Users/chsharri/Downloads/populations_copy.txt')
# note this is how it looks in MacOS, it will be different on a Windows PC
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 # note if the data file is in another folder, I have to add some path information to the file string
# ----> 3 data2 = np.loadtxt('/Users/chsharri/Downloads/populations_copy.txt')
#
# File ~\AppData\Local\anaconda3again\envs\OCS4001_2\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
# ...

# %%
data2

# %%
# you can also download it directly from the url:

data3 = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')

# %%
data3 # year, hare, lynx, carrot are the columns
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
help(np.loadtxt)
# Out:
# Help on function loadtxt in module numpy:
#
# loadtxt(fname, dtype=<class 'float'>, comments='#', delimiter=None, converters=None, skiprows=0, usecols=None, unpack=False, ndmin=0, encoding='bytes', max_rows=None, *, quotechar=None, like=None)
#     Load data from a text file.
#
#     Parameters
#     ----------
#     fname : file, str, pathlib.Path, list of str, generator
#         File, filename, list, or generator to read.  If the filename
#         extension is ``.gz`` or ``.bz2``, the file is first decompressed. Note
#         that generators must return bytes or strings. The strings
#         in a list or produced by a generator are treated as lines.
#     dtype : data-type, optional
#         Data-type of the resulting array; default: float.  If this is a
#         structured data-type, the resulting array will be 1-dimensional, and
#         each row will be interpreted as an element of the array.  In this
# ...

# %% [markdown]
# Note that the header information (the names of the data columns) was not imported.

# %%
data=data3

# %%
# what is the shape of the data?
data.shape
# Out:
# (21, 4)

# %% [markdown]
# I want to plot the data in the three columns by year

# %%
# how do I get the years?
data[:,0]
# Out:
# array([1900., 1901., 1902., 1903., 1904., 1905., 1906., 1907., 1908.,
#        1909., 1910., 1911., 1912., 1913., 1914., 1915., 1916., 1917.,
#        1918., 1919., 1920.])

# %%
# how do I get the hare data?

data[:,1]
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
# let's make a plot hares vs. years
# syntax plt.plot(x, y) or plt.plot(year, data I want to plot) pseudocode
plt.plot(data[:,0],data[:,1])

# %%
# let's plot the rest of the data and add a legend
plt.plot(data[:,0],data[:,1], label='hares')
plt.plot(data[:,0],data[:,2],label='lynx')
plt.plot(data[:,0],data[:,3],label='carrot')
plt.legend()
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %% [markdown]
# ### 3.2.3 Now for the easy way with pandas

# %% [markdown]
# The hardest part is always getting the data loaded in properly

# %%
# import the data with pandas

data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt')

# %%
data_pd #want to get rid of /t since it is tab seperated, while this one is tab seperated
# Out:
#      # year\thare\tlynx\tcarrot
# 0        1900\t30e3\t4e3\t48300
# 1    1901\t47.2e3\t6.1e3\t48200
# 2    1902\t70.2e3\t9.8e3\t41500
# 3   1903\t77.4e3\t35.2e3\t38200
# 4   1904\t36.3e3\t59.4e3\t40600
# 5   1905\t20.6e3\t41.7e3\t39800
# 6     1906\t18.1e3\t19e3\t38600
# 7     1907\t21.4e3\t13e3\t42300
# 8      1908\t22e3\t8.3e3\t44500
# 9    1909\t25.4e3\t9.1e3\t42100
# 10   1910\t27.1e3\t7.4e3\t46000
# 11     1911\t40.3e3\t8e3\t46800
# 12    1912\t57e3\t12.3e3\t43800
# 13  1913\t76.6e3\t19.5e3\t40900
# 14  1914\t52.3e3\t45.7e3\t39400
# 15  1915\t19.5e3\t51.1e3\t39000
# 16  1916\t11.2e3\t29.7e3\t36700
# 17   1917\t7.6e3\t15.8e3\t41800
# 18   1918\t14.6e3\t9.7e3\t43300
# 19  1919\t16.2e3\t10.1e3\t41300
# 20   1920\t24.7e3\t8.6e3\t47300

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt',  sep = '\t'    ) #sep is to define what is between data points
data_pd

# I still don't like the numbers in the left column
# Out:
#     # year     hare     lynx  carrot
# 0     1900  30000.0   4000.0   48300
# 1     1901  47200.0   6100.0   48200
# 2     1902  70200.0   9800.0   41500
# 3     1903  77400.0  35200.0   38200
# 4     1904  36300.0  59400.0   40600
# 5     1905  20600.0  41700.0   39800
# 6     1906  18100.0  19000.0   38600
# 7     1907  21400.0  13000.0   42300
# 8     1908  22000.0   8300.0   44500
# 9     1909  25400.0   9100.0   42100
# 10    1910  27100.0   7400.0   46000
# 11    1911  40300.0   8000.0   46800
# 12    1912  57000.0  12300.0   43800
# 13    1913  76600.0  19500.0   40900
# 14    1914  52300.0  45700.0   39400
# 15    1915  19500.0  51100.0   39000
# 16    1916  11200.0  29700.0   36700
# 17    1917   7600.0  15800.0   41800
# 18    1918  14600.0   9700.0   43300
# 19    1919  16200.0  10100.0   41300
# 20    1920  24700.0   8600.0   47300

# %%
data_pd = pd.read_csv('http://scipy-lectures.org/_downloads/populations.txt', sep = '\t', index_col = '# year')
data_pd

# that worked!
# Out:
#            hare     lynx  carrot
# # year
# 1900    30000.0   4000.0   48300
# 1901    47200.0   6100.0   48200
# 1902    70200.0   9800.0   41500
# 1903    77400.0  35200.0   38200
# 1904    36300.0  59400.0   40600
# 1905    20600.0  41700.0   39800
# 1906    18100.0  19000.0   38600
# 1907    21400.0  13000.0   42300
# 1908    22000.0   8300.0   44500
# 1909    25400.0   9100.0   42100
# 1910    27100.0   7400.0   46000
# 1911    40300.0   8000.0   46800
# 1912    57000.0  12300.0   43800
# 1913    76600.0  19500.0   40900
# 1914    52300.0  45700.0   39400
# 1915    19500.0  51100.0   39000
# 1916    11200.0  29700.0   36700
# 1917     7600.0  15800.0   41800
# 1918    14600.0   9700.0   43300
# 1919    16200.0  10100.0   41300
# 1920    24700.0   8600.0   47300

# %%
data_pd.plot(xlabel = 'Years', ylabel = "Population")

# wow, so easy...
# Out:
# <Axes: xlabel='Years', ylabel='Population'>

# %% [markdown]
# Lots of examples in the docs:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ### In your last exercise, you will upload some data of your choosing and make a scientific plot using what you learned today

# %% [markdown]
# # Exercises 3.2

# %% [markdown]
# **E.1** Complete Ch 2 of intermediate python on datacamp. Make sure you submit your completed **score**, not just the percent completed.

# %% [markdown]
# **E.2** What is a dictionary and why is it useful?

# %%
#a dictionary is similar to a list where it stores a set of strings, booleans, and integers. They are categorized and can be called using keys instead of just location within the list.
# It is useful to use a dictionary when you have data that is easily categorized and has multiple rows and columns

# %% [markdown]
# **E.3** How do you define a dictionary and access its elements? Explain. Now Define a dictionary that has names of people in your family or friend group, including yourself, with their age, hairstyle, and pet type. (Use 'none' if they don't have a pet)

# %%
# A dictionary is defined and accessed using keys instead of location on the list.
my_dict={'name':['sarah','katie','susan','matt'],'age':['25','22','62','36'],'hairstyle':['curly long','wavy long','curly short','straight short'],'pet_type':[None,'cat','lab','bulldog']}
print(my_dict)
# Out:
# {'name': ['sarah', 'katie', 'susan', 'matt'], 'age': ['25', '22', '62', '36'], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short'], 'pet_type': [None, 'cat', 'lab', 'bulldog']}

# %% [markdown]
# **E.4** What is a dictionary "key" in python? Can key names be changed once they are created? Demonstrate. Say you spelled your family member's name wrong, how can you correct it? What about their pet type?

# %%
# a dictionary key is the name of the category in the dictionary. For example, for my_dict, the key is 'name', 'age', etc
# Keys cannot be changed once they are created
my_dict['name']='first name' #example that its incorrect

# %%
print(my_dict) # it changes the entire group instead of just the key name
# Out:
# {'name': ['Sarah', 'katie', 'susan', 'matt', 'jean', 'miriam'], 'age': ['25', '22', '62', '36', '27', 27], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short', 'long straight', 'long straight'], 'pet_type': ['fish', 'cat', 'lab', 'bulldog', 'siamese cat', None]}

# %%
my_dict={'name':['sarah','katie','susan','matt'],'age':['25','22','62','36'],'hairstyle':['curly long','wavy long','curly short','straight short'],'pet_type':[None,'cat','lab','bulldog']}
# to correct name in the dictionary
my_dict['name'][0]='Sarah'
print(my_dict)

# to correct pet type
my_dict['pet_type'][0]='fish'
print(my_dict)
# Out:
# {'name': ['Sarah', 'katie', 'susan', 'matt'], 'age': ['25', '22', '62', '36'], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short'], 'pet_type': [None, 'cat', 'lab', 'bulldog']}
# {'name': ['Sarah', 'katie', 'susan', 'matt'], 'age': ['25', '22', '62', '36'], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short'], 'pet_type': ['fish', 'cat', 'lab', 'bulldog']}

# %% [markdown]
# **E.5** Add an entry to your dictionary above and delete another entry

# %%
# add entry
entry={'name':'jean','age':'27','hairstyle':'long straight','pet_type':'siamese cat'}
my_dict['name'].append(entry['name'])
my_dict['age'].append(entry['age'])
my_dict['hairstyle'].append(entry['hairstyle'])
my_dict['pet_type'].append(entry['pet_type'])
print(my_dict)
# Out:
# {'name': ['Sarah', 'katie', 'susan', 'matt', 'jean'], 'age': ['25', '22', '62', '36', '27'], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short', 'long straight'], 'pet_type': ['fish', 'cat', 'lab', 'bulldog', 'siamese cat']}

# %% [markdown]
# **E.6** Create a sub-dictionary containing the information above your your lab parner. Add this to your main dictionairy from E.3 and print out the result

# %%
lab_partner={'name':'miriam','age':27,'hairstyle':'long straight','pet_type':None}
my_dict['name'].append(lab_partner['name'])
my_dict['age'].append(lab_partner['age'])
my_dict['hairstyle'].append(lab_partner['hairstyle'])
my_dict['pet_type'].append(lab_partner['pet_type'])
print(my_dict)
# Out:
# {'name': ['Sarah', 'katie', 'susan', 'matt', 'jean', 'miriam'], 'age': ['25', '22', '62', '36', '27', 27], 'hairstyle': ['curly long', 'wavy long', 'curly short', 'straight short', 'long straight', 'long straight'], 'pet_type': ['fish', 'cat', 'lab', 'bulldog', 'siamese cat', None]}

# %% [markdown]
# **E.7** What is the common import statement for pandas?

# %%
import pandas as pd

# %% [markdown]
# **E.8** For what kinds of data are pandas dataframes more useful than numpy arrays?

# %%
# pandas dataframes are more useful for datasets multiple types of data for each column. For example, if you have a dataframe where one column is strings, the next is Booleans, and one is floats

# %% [markdown]
# **E.9** Convert your dictionary to a pandas dataframe

# %%
dataframe_practice=pd.DataFrame(my_dict)

# %% [markdown]
# **E.10** Save your dictionary as a csv file open this in Excel. **Submit a screenshot of your excel spreadsheet**

# %%
dataframe_practice.to_csv('practice.csv')

# %%
#tried this but I will also include the image in moodle
from IPython.display import Image
image=
Imag(e"C/\User/\sbrann/\OneDrive - Louisiana State Universit/\May13_backu/\Classwor/\python_cours/\lab3./\Screenshot 2024-09-12 125220.pngg
)
# Out:
#   Cell In[206], line 3
#     Imag(e"C/\User/\sbrann/\OneDrive - Louisiana State Universit/\May13_backu/\Classwor/\python_cours/\lab3./\Screenshot 2024-09-12 125220.pngg
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# **E.11** In Excel, add another person to your dictionary data. Save this and import the updated csv file as a pandas dataframe. Print the result.

# %%
dataframe_practice2=pd.read_csv("C:/Users/sbrann5/OneDrive - Louisiana State University/May13_backup/Classwork/python_course/lab3.2/practice2.csv")
print(dataframe_practice2)
# Out:
#    Unnamed: 0    name  age       hairstyle     pet_type
# 0           0   Sarah   25      curly long         fish
# 1           1   katie   22       wavy long          cat
# 2           2   susan   62     curly short          lab
# 3           3    matt   36  straight short      bulldog
# 4           4    jean   27   long straight  siamese cat
# 5           5  miriam   27   long straight          NaN
# 6           6   keith   32     short curly    dachshund

# %% [markdown]
# **E.12** What does the index_col option do when you load in data to a pandas dataframe? Check out the documentation for loading a file into a dataframe. Find another option and explain when it would be useful.

# %%
# the index_col option can specify if one of the columns is just numbers instead of real data. When I exported this dataframe as a .csv, the first column is just a list of numbers

# read.csv(header=0) can be used when there is a header row and you want to indicate that is it there instead of a row of a normal row

dataframe_practice2=pd.read_csv("C:/Users/sbrann5/OneDrive - Louisiana State University/May13_backup/Classwork/python_course/lab3.2/practice2.csv",index_col=1)
print(dataframe_practice2)
type(dataframe_practice2)
# Out:
#         Unnamed: 0  age       hairstyle     pet_type
# name
# Sarah            0   25      curly long         fish
# katie            1   22       wavy long          cat
# susan            2   62     curly short          lab
# matt             3   36  straight short      bulldog
# jean             4   27   long straight  siamese cat
# miriam           5   27   long straight          NaN
# keith            6   32     short curly    dachshund
# pandas.core.frame.DataFrame

# %% [markdown]
# **E.13** What is the difference between the loc and iloc methods? Explain

# %%
# both methods allow you to locate entries in a pandas dataframe, but the .loc is called using the row/column names while the .iloc is by the row.column number

# %% [markdown]
# **E.14** Now demonstrate. Print out both the hairstyle and pet type of your lab partner together (in the same line of code), first using the loc method and then with the iloc method.

# %%
print(dataframe_practice2)
# Out:
#         Unnamed: 0  age       hairstyle     pet_type
# name
# Sarah            0   25      curly long         fish
# katie            1   22       wavy long          cat
# susan            2   62     curly short          lab
# matt             3   36  straight short      bulldog
# jean             4   27   long straight  siamese cat
# miriam           5   27   long straight          NaN
# keith            6   32     short curly    dachshund

# %%
dataframe_practice2.loc['miriam','hairstyle']
# Out:
# 'long straight'

# %% [markdown]
# **E.15** Define a subdataframe that has only you and your lab partner, and only your ages and hairstyles. Print this out

# %%
dataframe_practice2.loc[['miriam','Sarah'],['age','hairstyle']]
# Out:
#         age      hairstyle
# name
# miriam   27  long straight
# Sarah    25     curly long

# %% [markdown]
# **E.16** What does the : symbol mean in indexing? Explain and give an example

# %%
# the : means to select the values associated with a specific key in a dictionary
example={'dog':'lucky'}
print(example['dog'])
# Out:
# lucky

# %% [markdown]
# **E.17** Now define a subdataframe that has all the people in your dictionary's pet type. Print this out

# %%
dataframe_practice3=dataframe_practice2.loc[:,'pet_type']
print(dataframe_practice3)
# Out:
# name
# Sarah            fish
# katie             cat
# susan             lab
# matt          bulldog
# jean      siamese cat
# miriam            NaN
# keith       dachshund
# Name: pet_type, dtype: object

# %% [markdown]
# **E.18** Upload the population data used in the lecture and plot just the carrots data using pandas. Label your plot appropriately

# %%
print(data)
# Out:
# [[ 1900. 30000.  4000. 48300.]
#  [ 1901. 47200.  6100. 48200.]
#  [ 1902. 70200.  9800. 41500.]
#  [ 1903. 77400. 35200. 38200.]
#  [ 1904. 36300. 59400. 40600.]
#  [ 1905. 20600. 41700. 39800.]
#  [ 1906. 18100. 19000. 38600.]
#  [ 1907. 21400. 13000. 42300.]
#  [ 1908. 22000.  8300. 44500.]
#  [ 1909. 25400.  9100. 42100.]
#  [ 1910. 27100.  7400. 46000.]
#  [ 1911. 40300.  8000. 46800.]
#  [ 1912. 57000. 12300. 43800.]
#  [ 1913. 76600. 19500. 40900.]
#  [ 1914. 52300. 45700. 39400.]
#  [ 1915. 19500. 51100. 39000.]
#  [ 1916. 11200. 29700. 36700.]
#  [ 1917.  7600. 15800. 41800.]
#  [ 1918. 14600.  9700. 43300.]
#  [ 1919. 16200. 10100. 41300.]
#  [ 1920. 24700.  8600. 47300.]]

# %%
data_dataframe=pd.DataFrame(data)
print(data_dataframe)
# carrots are column 4
plt.plot(data_dataframe[0],data_dataframe[3])
plt.xlabel('year')
plt.ylabel('carrots')
# Out:
#          0        1        2        3
# 0   1900.0  30000.0   4000.0  48300.0
# 1   1901.0  47200.0   6100.0  48200.0
# 2   1902.0  70200.0   9800.0  41500.0
# 3   1903.0  77400.0  35200.0  38200.0
# 4   1904.0  36300.0  59400.0  40600.0
# 5   1905.0  20600.0  41700.0  39800.0
# 6   1906.0  18100.0  19000.0  38600.0
# 7   1907.0  21400.0  13000.0  42300.0
# 8   1908.0  22000.0   8300.0  44500.0
# 9   1909.0  25400.0   9100.0  42100.0
# 10  1910.0  27100.0   7400.0  46000.0
# 11  1911.0  40300.0   8000.0  46800.0
# 12  1912.0  57000.0  12300.0  43800.0
# 13  1913.0  76600.0  19500.0  40900.0
# 14  1914.0  52300.0  45700.0  39400.0
# 15  1915.0  19500.0  51100.0  39000.0
# 16  1916.0  11200.0  29700.0  36700.0
# 17  1917.0   7600.0  15800.0  41800.0
# 18  1918.0  14600.0   9700.0  43300.0
# 19  1919.0  16200.0  10100.0  41300.0
# 20  1920.0  24700.0   8600.0  47300.0
# Text(0, 0.5, 'carrots')

# %% [markdown]
# ## **E.19** My First Scientific Python Plot
# ### You will present this in class next Thursday
#
# Find a csv file with some scientific data, ideally some data you collected, or someone in your lab collected, or a friend of yours collected. It has to be some real data
#
# **E.19.1** Upload your data into pandas. Make sure the dataframe is loaded correctly (look at the data).
#
# **E.19.2** Make a table of a subset of the data. (Hint: use my_dataframe[subset_here].table() method)
# Write a table caption that explains what your table is.
#
# **E.19.3** Make a plot of some relevant subset of the data (or all of it, if appropriate), label your axes and write a figure caption
#
# **E.19.4** Do some analysis on your data, like finding the maximum, some basic statistics, etc.. Write some text explaining your methods and your results.

# %%
ADCP=pd.read_excel("C:/Users/sbrann5/OneDrive - Louisiana State University/May13_backup/Fieldwork/ADCP_South_Pass_all/ADCP_Survey_data_may24.xlsx")

# %%
#remove rows that are not directly on south pass
ADCP.drop([4,6,13,14,15],inplace=True)

#print(ADCP)

# %%
#make a table
march=march_ADCP.loc[:,['meters_downriver','Total_Q_Averaged_(m^3/s)3']]
print(march)
#This table is for the discharge at each transect during our March data collection.
# Out:
#     meters_downriver  Total_Q_Averaged_(m^3/s)3
# 0             0.0000                    1768.00
# 1             0.0000                    1784.00
# 2         17541.8060                     134.64
# 3         15192.1696                     223.50
# 5         14709.3676                     257.20
# 7         14065.6316                     212.10
# 8         12633.3190                     254.80
# 9         10299.7760                     589.60
# 10         7612.1782                     870.80
# 11         4876.3002                    1071.40
# 12         4329.1246                    1534.10
# 16         2574.9440                    1633.80

# %%
march_ADCP=ADCP[['meters_downriver','Total_Q_Averaged_(m^3/s)3']]
#print(march_ADCP)
x=march_ADCP.loc[:,['meters_downriver']]
y=march_ADCP.loc[:,['Total_Q_Averaged_(m^3/s)3']]
y1=ADCP.loc[:,['Total_Q_Averaged_(m^3/s)5_24']]
y2=ADCP.loc[:,['Total_Q_Averaged_(m^3/s)9']]


plt.scatter(x,y, label='March 2023')
plt.scatter(x,y1, label='May 2024')
plt.scatter(x,y2, label='Sept 2023')
plt.legend()
plt.xlabel('distance down south pass [m] \n \n \n This figure shows the volume of water passes through different \n transects along South Pass')
plt.ylabel('discharge [cms]')
plt.show()

# %%
#normalize values by the top of head of passes discharge

print(y.loc[0])
normalized_march=(y/y.loc[0])*100
normalized_may=(y1/y1.loc[0])*100
normalized_sept=(y2/y2.loc[0])*100

plt.scatter(x,normalized_march, label='March 2023')
plt.scatter(x,normalized_may, label='May 2024')
plt.scatter(x,normalized_sept, label='Sept 2023')
plt.xlabel('distance down south pass [m]')
plt.ylabel('fraction of discharge at head of passes [%]')
plt.legend()
plt.show()
# Out:
# Total_Q_Averaged_(m^3/s)3    1768.0
# Name: 0, dtype: float64

# %%
# The normalized discharge values are effective at showing how the different in the vegetation impacts the amount of discharge that stays within the
# channel instead of going over the banks toward the vegetation. When the vegetation is highest in May and September, a larger fraction is kept
# within the channel, while in March when vegetation is sparser, a lower fraction stays within the channel

# %%
dir(y)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
total_lost_march=y.max()-y.min()
print('march total discharge loss',total_lost_march)
total_lost_may=y1.max()-y1.min()
print('may total discharge loss',total_lost_may)
total_lost_sept=y2.max()-y2.min()
print('september total discharge loss',total_lost_sept)
# Out:
# march total discharge loss Total_Q_Averaged_(m^3/s)3    1649.36
# dtype: float64
# may total discharge loss Total_Q_Averaged_(m^3/s)5_24    1146.465
# dtype: float64
# september total discharge loss Total_Q_Averaged_(m^3/s)9    1001.116
# dtype: float64

# %% [raw]
# For my analysis, I decided to compare the highest and lowest discharges in order to see the total discharge loss over the entirity of South Pass. This is helpful information to see the seasonal changes in discharge over the entire Mississippi River Basin. In order to do this, I subtracted the minimumm from the maximum discharge. March has the highest discharge difference, which is explained by peak stage of the Mississippi River due to snowmelt from the Northern US. September has the lowest change in discharge since it has the lowest discharge overall due to it being the end of the summer.
# I also computer the normalized discharge in order to focus on the effect of vegetation seperately from the basin-scale discharge change.
